# %% [markdown]
# # 📦 Data Contract — Análise Long Neck WSNP (NENO)
#
# **Projeto:** Planejamento de Supply Chain — Embalagens Long Neck — Região NENO
# **Empresa:** Ambev
# **Arquivo de dados:** `Analise_LongNeck_WSNP_-_Sem_repostas.xlsb`
# **Data de referência:** Fevereiro/2026 (W0: 02/02/2026)
#
# ---
#
# Este notebook documenta o **Data Contract** do projeto, descrevendo cada variável presente nas abas do arquivo Excel de planejamento logístico da Ambev para a linha Long Neck na região Nordeste (NENO).

# %% [markdown]
# ## 1. Contexto da Dor do Cliente
#
# A região **Nordeste (NENO)** da Ambev apresenta crescimento consistente no volume de marcas premium, com destaque para a embalagem **Long Neck (LN)**. A capacidade produtiva local está próxima do limite, gerando necessidade de transferências externas (principalmente de SP e MG) para suprir a demanda.
#
# **Situação-problema:** As regiões Geo Nordeste e Geo Norte solicitaram um aumento de **30% na demanda de Malzbier Brahma para Fevereiro/2026**, além de sinalização de **+10% no total de LN a partir de Março**. Isso pressiona ainda mais a capacidade já limitada da região.
#
# **Perguntas a responder:**
# 1. Devemos seguir com os incentivos comerciais?
# 2. Qual será o plano de produção e transferência para atendimento das novas demandas?
# 3. Quanto vai custar a operação?
# 4. Quais os riscos envolvidos?
#
# **Premissas:**
# - Restrições produtivas e logísticas vigentes
# - Custos de transferência ex-Nordeste (ex-NE)
# - **DOI mínimo de 12 dias** para a região NENO

# %% [markdown]
# ## 2. Importação de Bibliotecas

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, HTML

# Configuração de exibição das tabelas
pd.set_option('display.max_colwidth', None)

def exibir_tabela(df, largura_descricao='520px'):
    """
    Exibe um DataFrame com formatação completa:
    - Largura total da célula
    - Quebra de linha automática na coluna Descrição
    - Sem truncamento de texto
    """
    estilos = [
        dict(selector='table', props=[('width', '100%'), ('border-collapse', 'collapse'), ('font-size', '13px'), ('font-family', 'Arial, sans-serif')]),
        dict(selector='th', props=[('background-color', '#2c2c2c'), ('color', '#ffffff'), ('padding', '8px 12px'), ('text-align', 'left'), ('white-space', 'nowrap')]),
        dict(selector='td', props=[('padding', '7px 12px'), ('border-bottom', '1px solid #e0e0e0'), ('vertical-align', 'top'), ('white-space', 'normal'), ('word-wrap', 'break-word')]),
        dict(selector='tr:nth-child(even)', props=[('background-color', '#f8f8f8')]),
        dict(selector='tr:hover', props=[('background-color', '#fff3cd')]),
    ]
    styled = df.style.set_table_styles(estilos).hide(axis='index')
    # Aplica largura específica à coluna Descrição quando existir
    if 'Descrição' in df.columns:
        styled = styled.set_properties(subset=['Descrição'], **{'min-width': largura_descricao, 'white-space': 'normal'})
    if 'Restrição' in df.columns:
        styled = styled.set_properties(subset=['Restrição'], **{'min-width': largura_descricao, 'white-space': 'normal'})
    if 'Atende' in df.columns:
        styled = styled.set_properties(subset=['Atende'], **{'min-width': '200px', 'white-space': 'normal'})
    display(styled)

print('Bibliotecas importadas e configurações aplicadas com sucesso.')
# Out:
# Bibliotecas importadas e configurações aplicadas com sucesso.

# %% [markdown]
# ## 3. Data Contract
#
# O Data Contract é a documentação formal de cada variável presente no dataset. Garante alinhamento entre as áreas de negócio e dados, evitando ambiguidades na análise.

# %% [markdown]
# ### 3.1 Dimensões Gerais

# %%
dimensoes_gerais = pd.DataFrame([
    {'Nome da Coluna': 'GEO/REG',       'Tipo': 'str',   'Descrição': 'Sub-região geográfica de destino (ex: NE Norte, NE Sul, Mapapi, NO Araguaia, NO Centro)'},
    {'Nome da Coluna': 'SKU',           'Tipo': 'str',   'Descrição': 'Código identificador do produto no sistema (Stock Keeping Unit)'},
    {'Nome da Coluna': 'Desc Produto',  'Tipo': 'str',   'Descrição': 'Descrição completa do produto (ex: MALZBIER BRAHMA LN355ML SIX PAC BAND C/4)'},
    {'Nome da Coluna': 'Cod Produto',   'Tipo': 'str',   'Descrição': 'Código numérico do produto no sistema'},
    {'Nome da Coluna': 'Linha',         'Tipo': 'str',   'Descrição': 'Linha de envase associada ao produto (ex: L541)'},
    {'Nome da Coluna': 'Container Type','Tipo': 'str',   'Descrição': 'Tipo de embalagem Long Neck (LONG NECK 330ML, 355ML ou 269ML)'},
])

exibir_tabela(dimensoes_gerais)
# Out:
# <style type="text/css">
# #T_d1041 table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_d1041 th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_d1041 td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_d1041 tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_d1041 tr:hover {
#   background-color: #fff3cd;
# }
# #T_d1041_row0_col2, #T_d1041_row1_col2, #T_d1041_row2_col2, #T_d1041_row3_col2, #T_d1041_row4_col2, #T_d1041_row5_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_d1041">
#   <thead>
#     <tr>
#       <th id="T_d1041_level0_col0" class="col_heading level0 col0" >Nome da Coluna</th>
#       <th id="T_d1041_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_d1041_level0_col2" class="col_heading level0 col2" >Descrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d1041_row0_col0" class="data row0 col0" >GEO/REG</td>
#       <td id="T_d1041_row0_col1" class="data row0 col1" >str</td>
#       <td id="T_d1041_row0_col2" class="data row0 col2" >Sub-região geográfica de destino (ex: NE Norte, NE Sul, Mapapi, NO Araguaia, NO Centro)</td>
#     </tr>
#     <tr>
#       <td id="T_d1041_row1_col0" class="data row1 col0" >SKU</td>
#       <td id="T_d1041_row1_col1" class="data row1 col1" >str</td>
#       <td id="T_d1041_row1_col2" class="data row1 col2" >Código identificador do produto no sistema (Stock Keeping Unit)</td>
#     </tr>
#     <tr>
#       <td id="T_d1041_row2_col0" class="data row2 col0" >Desc Produto</td>
#       <td id="T_d1041_row2_col1" class="data row2 col1" >str</td>
#       <td id="T_d1041_row2_col2" class="data row2 col2" >Descrição completa do produto (ex: MALZBIER BRAHMA LN355ML SIX PAC BAND C/4)</td>
#     </tr>
#     <tr>
#       <td id="T_d1041_row3_col0" class="data row3 col0" >Cod Produto</td>
#       <td id="T_d1041_row3_col1" class="data row3 col1" >str</td>
#       <td id="T_d1041_row3_col2" class="data row3 col2" >Código numérico do produto no sistema</td>
#     </tr>
#     <tr>
#       <td id="T_d1041_row4_col0" class="data row4 col0" >Linha</td>
#       <td id="T_d1041_row4_col1" class="data row4 col1" >str</td>
#       <td id="T_d1041_row4_col2" class="data row4 col2" >Linha de envase associada ao produto (ex: L541)</td>
#     </tr>
#     <tr>
#       <td id="T_d1041_row5_col0" class="data row5 col0" >Container Type</td>
#       <td id="T_d1041_row5_col1" class="data row5 col1" >str</td>
#       <td id="T_d1041_row5_col2" class="data row5 col2" >Tipo de embalagem Long Neck (LONG NECK 330ML, 355ML ou 269ML)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.2 Produção

# %%
producao = pd.DataFrame([
    {'Nome da Coluna': 'PROD',                  'Tipo': 'float', 'Descrição': 'Volume total de produção planejada para o período (KHL)'},
    {'Nome da Coluna': 'Real',                  'Tipo': 'float', 'Descrição': 'Volume efetivamente realizado de produção no período (KHL)'},
    {'Nome da Coluna': 'WSNP',                  'Tipo': 'float', 'Descrição': 'Weekly Supply Network Planning — volume programado para produção na semana corrente (KHL)'},
    {'Nome da Coluna': '1W',                    'Tipo': 'float', 'Descrição': 'Volume programado para produção no mês — horizonte de 1 mês (KHL)'},
    {'Nome da Coluna': 'Nominal [grf/hora]',    'Tipo': 'float', 'Descrição': 'Capacidade nominal da linha produtiva em gramas por hora'},
    {'Nome da Coluna': 'Capacity Semanal [hl]', 'Tipo': 'float', 'Descrição': 'Capacidade disponível da linha produtiva em hectolitros por semana'},
    {'Nome da Coluna': 'Crítica PCPs',          'Tipo': 'str',   'Descrição': 'Restrições críticas apontadas pelo time de Planejamento e Controle da Produção'},
])

exibir_tabela(producao)
# Out:
# <style type="text/css">
# #T_0a380 table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_0a380 th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_0a380 td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_0a380 tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_0a380 tr:hover {
#   background-color: #fff3cd;
# }
# #T_0a380_row0_col2, #T_0a380_row1_col2, #T_0a380_row2_col2, #T_0a380_row3_col2, #T_0a380_row4_col2, #T_0a380_row5_col2, #T_0a380_row6_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_0a380">
#   <thead>
#     <tr>
#       <th id="T_0a380_level0_col0" class="col_heading level0 col0" >Nome da Coluna</th>
#       <th id="T_0a380_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_0a380_level0_col2" class="col_heading level0 col2" >Descrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a380_row0_col0" class="data row0 col0" >PROD</td>
#       <td id="T_0a380_row0_col1" class="data row0 col1" >float</td>
#       <td id="T_0a380_row0_col2" class="data row0 col2" >Volume total de produção planejada para o período (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_0a380_row1_col0" class="data row1 col0" >Real</td>
#       <td id="T_0a380_row1_col1" class="data row1 col1" >float</td>
#       <td id="T_0a380_row1_col2" class="data row1 col2" >Volume efetivamente realizado de produção no período (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_0a380_row2_col0" class="data row2 col0" >WSNP</td>
#       <td id="T_0a380_row2_col1" class="data row2 col1" >float</td>
#       <td id="T_0a380_row2_col2" class="data row2 col2" >Weekly Supply Network Planning — volume programado para produção na semana corrente (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_0a380_row3_col0" class="data row3 col0" >1W</td>
#       <td id="T_0a380_row3_col1" class="data row3 col1" >float</td>
#       <td id="T_0a380_row3_col2" class="data row3 col2" >Volume programado para produção no mês — horizonte de 1 mês (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_0a380_row4_col0" class="data row4 col0" >Nominal [grf/hora]</td>
#       <td id="T_0a380_row4_col1" class="data row4 col1" >float</td>
#       <td id="T_0a380_row4_col2" class="data row4 col2" >Capacidade nominal da linha produtiva em gramas por hora</td>
#     </tr>
#     <tr>
#       <td id="T_0a380_row5_col0" class="data row5 col0" >Capacity Semanal [hl]</td>
#       <td id="T_0a380_row5_col1" class="data row5 col1" >float</td>
#       <td id="T_0a380_row5_col2" class="data row5 col2" >Capacidade disponível da linha produtiva em hectolitros por semana</td>
#     </tr>
#     <tr>
#       <td id="T_0a380_row6_col0" class="data row6 col0" >Crítica PCPs</td>
#       <td id="T_0a380_row6_col1" class="data row6 col1" >str</td>
#       <td id="T_0a380_row6_col2" class="data row6 col2" >Restrições críticas apontadas pelo time de Planejamento e Controle da Produção</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.3 Estoque

# %%
estoque = pd.DataFrame([
    {'Nome da Coluna': 'EI Mês',     'Tipo': 'float', 'Descrição': 'Estoque Inicial do mês em hectolitros (KHL)'},
    {'Nome da Coluna': 'EI Semana',  'Tipo': 'float', 'Descrição': 'Estoque Inicial da semana em hectolitros (KHL)'},
    {'Nome da Coluna': 'EF Semana',  'Tipo': 'float', 'Descrição': 'Estoque Final da semana. Fórmula: EI + Transferências + Trânsito − Demanda (KHL)'},
    {'Nome da Coluna': 'EFM',        'Tipo': 'float', 'Descrição': 'Estoque Final do mês em hectolitros (KHL)'},
    {'Nome da Coluna': 'Suf.ini(d)', 'Tipo': 'int',   'Descrição': 'Suficiência inicial em dias: EI / linear de demanda diária'},
    {'Nome da Coluna': 'Suf. f (d)', 'Tipo': 'int',   'Descrição': 'Suficiência final em dias: EF / linear de demanda diária. DOI mínimo exigido: 12 dias'},
    {'Nome da Coluna': 'Trânsito',   'Tipo': 'float', 'Descrição': 'Volume em trânsito via cabotagem ainda não contabilizado no estoque local (KHL)'},
])

exibir_tabela(estoque)
# Out:
# <style type="text/css">
# #T_ac470 table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_ac470 th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_ac470 td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_ac470 tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_ac470 tr:hover {
#   background-color: #fff3cd;
# }
# #T_ac470_row0_col2, #T_ac470_row1_col2, #T_ac470_row2_col2, #T_ac470_row3_col2, #T_ac470_row4_col2, #T_ac470_row5_col2, #T_ac470_row6_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_ac470">
#   <thead>
#     <tr>
#       <th id="T_ac470_level0_col0" class="col_heading level0 col0" >Nome da Coluna</th>
#       <th id="T_ac470_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_ac470_level0_col2" class="col_heading level0 col2" >Descrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ac470_row0_col0" class="data row0 col0" >EI Mês</td>
#       <td id="T_ac470_row0_col1" class="data row0 col1" >float</td>
#       <td id="T_ac470_row0_col2" class="data row0 col2" >Estoque Inicial do mês em hectolitros (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_ac470_row1_col0" class="data row1 col0" >EI Semana</td>
#       <td id="T_ac470_row1_col1" class="data row1 col1" >float</td>
#       <td id="T_ac470_row1_col2" class="data row1 col2" >Estoque Inicial da semana em hectolitros (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_ac470_row2_col0" class="data row2 col0" >EF Semana</td>
#       <td id="T_ac470_row2_col1" class="data row2 col1" >float</td>
#       <td id="T_ac470_row2_col2" class="data row2 col2" >Estoque Final da semana. Fórmula: EI + Transferências + Trânsito − Demanda (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_ac470_row3_col0" class="data row3 col0" >EFM</td>
#       <td id="T_ac470_row3_col1" class="data row3 col1" >float</td>
#       <td id="T_ac470_row3_col2" class="data row3 col2" >Estoque Final do mês em hectolitros (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_ac470_row4_col0" class="data row4 col0" >Suf.ini(d)</td>
#       <td id="T_ac470_row4_col1" class="data row4 col1" >int</td>
#       <td id="T_ac470_row4_col2" class="data row4 col2" >Suficiência inicial em dias: EI / linear de demanda diária</td>
#     </tr>
#     <tr>
#       <td id="T_ac470_row5_col0" class="data row5 col0" >Suf. f (d)</td>
#       <td id="T_ac470_row5_col1" class="data row5 col1" >int</td>
#       <td id="T_ac470_row5_col2" class="data row5 col2" >Suficiência final em dias: EF / linear de demanda diária. DOI mínimo exigido: 12 dias</td>
#     </tr>
#     <tr>
#       <td id="T_ac470_row6_col0" class="data row6 col0" >Trânsito</td>
#       <td id="T_ac470_row6_col1" class="data row6 col1" >float</td>
#       <td id="T_ac470_row6_col2" class="data row6 col2" >Volume em trânsito via cabotagem ainda não contabilizado no estoque local (KHL)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.4 Transferências

# %%
transferencias = pd.DataFrame([
    {'Nome da Coluna': 'Transf. Malha',      'Tipo': 'float', 'Descrição': 'Volume líquido de transferência na malha. Positivo (+): recebe; Negativo (−): exporta (KHL)'},
    {'Nome da Coluna': 'Transf. Interna',    'Tipo': 'float', 'Descrição': 'Volume recebido (+) ou enviado (−) dentro da própria região NENO (KHL)'},
    {'Nome da Coluna': 'Transf. Ext (Cabo)', 'Tipo': 'float', 'Descrição': 'Volume recebido (+) ou enviado (−) para fora da região via cabotagem. Lead time: 25 dias (KHL)'},
    {'Nome da Coluna': 'Transf. Ext (Rodo)', 'Tipo': 'float', 'Descrição': 'Volume recebido (+) ou enviado (−) para fora da região via rodoviário. Lead time: 6 dias, custo 60% maior que cabo (KHL)'},
    {'Nome da Coluna': 'Modal',              'Tipo': 'str',   'Descrição': 'Modal de transporte da transferência (Cabotagem ou Rodoviário)'},
    {'Nome da Coluna': 'Regional Origem',    'Tipo': 'str',   'Descrição': 'Região de origem do produto (ex: REG SE, REG NE)'},
    {'Nome da Coluna': 'Origem',             'Tipo': 'str',   'Descrição': 'Unidade produtiva de origem (ex: BR16 - F. Jacareí - SP)'},
    {'Nome da Coluna': 'Geo Destino',        'Tipo': 'str',   'Descrição': 'Região geográfica de destino da transferência'},
    {'Nome da Coluna': 'Desc Destino',       'Tipo': 'str',   'Descrição': 'Descrição do ponto de destino (ex: CDR Bahia, F. Fonte Mata)'},
])

exibir_tabela(transferencias)
# Out:
# <style type="text/css">
# #T_c58c8 table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_c58c8 th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_c58c8 td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_c58c8 tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_c58c8 tr:hover {
#   background-color: #fff3cd;
# }
# #T_c58c8_row0_col2, #T_c58c8_row1_col2, #T_c58c8_row2_col2, #T_c58c8_row3_col2, #T_c58c8_row4_col2, #T_c58c8_row5_col2, #T_c58c8_row6_col2, #T_c58c8_row7_col2, #T_c58c8_row8_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_c58c8">
#   <thead>
#     <tr>
#       <th id="T_c58c8_level0_col0" class="col_heading level0 col0" >Nome da Coluna</th>
#       <th id="T_c58c8_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_c58c8_level0_col2" class="col_heading level0 col2" >Descrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c58c8_row0_col0" class="data row0 col0" >Transf. Malha</td>
#       <td id="T_c58c8_row0_col1" class="data row0 col1" >float</td>
#       <td id="T_c58c8_row0_col2" class="data row0 col2" >Volume líquido de transferência na malha. Positivo (+): recebe; Negativo (−): exporta (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row1_col0" class="data row1 col0" >Transf. Interna</td>
#       <td id="T_c58c8_row1_col1" class="data row1 col1" >float</td>
#       <td id="T_c58c8_row1_col2" class="data row1 col2" >Volume recebido (+) ou enviado (−) dentro da própria região NENO (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row2_col0" class="data row2 col0" >Transf. Ext (Cabo)</td>
#       <td id="T_c58c8_row2_col1" class="data row2 col1" >float</td>
#       <td id="T_c58c8_row2_col2" class="data row2 col2" >Volume recebido (+) ou enviado (−) para fora da região via cabotagem. Lead time: 25 dias (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row3_col0" class="data row3 col0" >Transf. Ext (Rodo)</td>
#       <td id="T_c58c8_row3_col1" class="data row3 col1" >float</td>
#       <td id="T_c58c8_row3_col2" class="data row3 col2" >Volume recebido (+) ou enviado (−) para fora da região via rodoviário. Lead time: 6 dias, custo 60% maior que cabo (KHL)</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row4_col0" class="data row4 col0" >Modal</td>
#       <td id="T_c58c8_row4_col1" class="data row4 col1" >str</td>
#       <td id="T_c58c8_row4_col2" class="data row4 col2" >Modal de transporte da transferência (Cabotagem ou Rodoviário)</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row5_col0" class="data row5 col0" >Regional Origem</td>
#       <td id="T_c58c8_row5_col1" class="data row5 col1" >str</td>
#       <td id="T_c58c8_row5_col2" class="data row5 col2" >Região de origem do produto (ex: REG SE, REG NE)</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row6_col0" class="data row6 col0" >Origem</td>
#       <td id="T_c58c8_row6_col1" class="data row6 col1" >str</td>
#       <td id="T_c58c8_row6_col2" class="data row6 col2" >Unidade produtiva de origem (ex: BR16 - F. Jacareí - SP)</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row7_col0" class="data row7 col0" >Geo Destino</td>
#       <td id="T_c58c8_row7_col1" class="data row7 col1" >str</td>
#       <td id="T_c58c8_row7_col2" class="data row7 col2" >Região geográfica de destino da transferência</td>
#     </tr>
#     <tr>
#       <td id="T_c58c8_row8_col0" class="data row8 col0" >Desc Destino</td>
#       <td id="T_c58c8_row8_col1" class="data row8 col1" >str</td>
#       <td id="T_c58c8_row8_col2" class="data row8 col2" >Descrição do ponto de destino (ex: CDR Bahia, F. Fonte Mata)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.5 Demanda

# %%
demanda = pd.DataFrame([
    {'Nome da Coluna': 'Demanda', 'Tipo': 'float', 'Descrição': 'Volume previsto de venda para o período em hectolitros (KHL)'},
])

exibir_tabela(demanda)
# Out:
# <style type="text/css">
# #T_f549a table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_f549a th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_f549a td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_f549a tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_f549a tr:hover {
#   background-color: #fff3cd;
# }
# #T_f549a_row0_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_f549a">
#   <thead>
#     <tr>
#       <th id="T_f549a_level0_col0" class="col_heading level0 col0" >Nome da Coluna</th>
#       <th id="T_f549a_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_f549a_level0_col2" class="col_heading level0 col2" >Descrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f549a_row0_col0" class="data row0 col0" >Demanda</td>
#       <td id="T_f549a_row0_col1" class="data row0 col1" >float</td>
#       <td id="T_f549a_row0_col2" class="data row0 col2" >Volume previsto de venda para o período em hectolitros (KHL)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.6 Custos

# %%
custos = pd.DataFrame([
    {'Nome da Coluna': 'Reais / HL',              'Tipo': 'float', 'Descrição': 'Custo unitário de transferência em reais por hectolitro (R$/HL)'},
    {'Nome da Coluna': 'Custo de Transferências', 'Tipo': 'float', 'Descrição': 'Custo total das transferências externas realizadas no período (R$)'},
    {'Nome da Coluna': 'MACOs - Produção Interna','Tipo': 'float', 'Descrição': 'Margem de contribuição quando a produção ocorre dentro da região NENO (R$)'},
    {'Nome da Coluna': 'Custo de Produção',       'Tipo': 'float', 'Descrição': 'Custo total de produção do SKU no período (R$)'},
])

exibir_tabela(custos)
# Out:
# <style type="text/css">
# #T_673eb table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_673eb th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_673eb td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_673eb tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_673eb tr:hover {
#   background-color: #fff3cd;
# }
# #T_673eb_row0_col2, #T_673eb_row1_col2, #T_673eb_row2_col2, #T_673eb_row3_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_673eb">
#   <thead>
#     <tr>
#       <th id="T_673eb_level0_col0" class="col_heading level0 col0" >Nome da Coluna</th>
#       <th id="T_673eb_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_673eb_level0_col2" class="col_heading level0 col2" >Descrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_673eb_row0_col0" class="data row0 col0" >Reais / HL</td>
#       <td id="T_673eb_row0_col1" class="data row0 col1" >float</td>
#       <td id="T_673eb_row0_col2" class="data row0 col2" >Custo unitário de transferência em reais por hectolitro (R$/HL)</td>
#     </tr>
#     <tr>
#       <td id="T_673eb_row1_col0" class="data row1 col0" >Custo de Transferências</td>
#       <td id="T_673eb_row1_col1" class="data row1 col1" >float</td>
#       <td id="T_673eb_row1_col2" class="data row1 col2" >Custo total das transferências externas realizadas no período (R$)</td>
#     </tr>
#     <tr>
#       <td id="T_673eb_row2_col0" class="data row2 col0" >MACOs - Produção Interna</td>
#       <td id="T_673eb_row2_col1" class="data row2 col1" >float</td>
#       <td id="T_673eb_row2_col2" class="data row2 col2" >Margem de contribuição quando a produção ocorre dentro da região NENO (R$)</td>
#     </tr>
#     <tr>
#       <td id="T_673eb_row3_col0" class="data row3 col0" >Custo de Produção</td>
#       <td id="T_673eb_row3_col1" class="data row3 col1" >float</td>
#       <td id="T_673eb_row3_col2" class="data row3 col2" >Custo total de produção do SKU no período (R$)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.7 Semanas de Planejamento

# %%
semanas = pd.DataFrame([
    {'Nome da Coluna': 'W0 - 02/02/2026', 'Tipo': 'date', 'Descrição': 'Semana 0 — semana corrente de referência do planejamento'},
    {'Nome da Coluna': 'W1 - 09/02/2026', 'Tipo': 'date', 'Descrição': 'Semana 1 — primeira semana de planejamento futuro'},
    {'Nome da Coluna': 'W2 - 16/02/2026', 'Tipo': 'date', 'Descrição': 'Semana 2 — segunda semana de planejamento futuro'},
    {'Nome da Coluna': 'W3 - 23/02/2026', 'Tipo': 'date', 'Descrição': 'Semana 3 — terceira semana de planejamento futuro'},
])

exibir_tabela(semanas)
# Out:
# <style type="text/css">
# #T_d9c69 table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_d9c69 th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_d9c69 td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_d9c69 tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_d9c69 tr:hover {
#   background-color: #fff3cd;
# }
# #T_d9c69_row0_col2, #T_d9c69_row1_col2, #T_d9c69_row2_col2, #T_d9c69_row3_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_d9c69">
#   <thead>
#     <tr>
#       <th id="T_d9c69_level0_col0" class="col_heading level0 col0" >Nome da Coluna</th>
#       <th id="T_d9c69_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_d9c69_level0_col2" class="col_heading level0 col2" >Descrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d9c69_row0_col0" class="data row0 col0" >W0 - 02/02/2026</td>
#       <td id="T_d9c69_row0_col1" class="data row0 col1" >date</td>
#       <td id="T_d9c69_row0_col2" class="data row0 col2" >Semana 0 — semana corrente de referência do planejamento</td>
#     </tr>
#     <tr>
#       <td id="T_d9c69_row1_col0" class="data row1 col0" >W1 - 09/02/2026</td>
#       <td id="T_d9c69_row1_col1" class="data row1 col1" >date</td>
#       <td id="T_d9c69_row1_col2" class="data row1 col2" >Semana 1 — primeira semana de planejamento futuro</td>
#     </tr>
#     <tr>
#       <td id="T_d9c69_row2_col0" class="data row2 col0" >W2 - 16/02/2026</td>
#       <td id="T_d9c69_row2_col1" class="data row2 col1" >date</td>
#       <td id="T_d9c69_row2_col2" class="data row2 col2" >Semana 2 — segunda semana de planejamento futuro</td>
#     </tr>
#     <tr>
#       <td id="T_d9c69_row3_col0" class="data row3 col0" >W3 - 23/02/2026</td>
#       <td id="T_d9c69_row3_col1" class="data row3 col1" >date</td>
#       <td id="T_d9c69_row3_col2" class="data row3 col2" >Semana 3 — terceira semana de planejamento futuro</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.8 Unidades Produtivas e CDRs

# %%
unidades = pd.DataFrame([
    {'Código':  'AQ541 / BR03', 'Nome': 'F. Aquiraz',              'Tipo': 'Cervejaria',              'Localização': 'NO Centro (CE)', 'Atende':                    'Todo o Nordeste e Manaus'},
    {'Código':  'NS541 / BR31', 'Nome': 'F. Pernambuco',           'Tipo': 'Cervejaria',              'Localização': 'NE Norte (PE)',  'Atende':                    'Todo o Nordeste'},
    {'Código':  'BR06',         'Nome': 'CDR João Pessoa',         'Tipo': 'Centro de Distribuição',  'Localização': 'NE Norte (PB)',  'Atende':                    'NE Norte, NO Centro, Mapapi'},
    {'Código':  'BR04',         'Nome': 'CDR Camaçari / Bahia',    'Tipo': 'Centro de Distribuição',  'Localização': 'NE Sul (BA)',    'Atende':                    'NE Sul'},
    {'Código':  'BR16',         'Nome': 'F. Jacareí',              'Tipo': 'Cervejaria',              'Localização': 'SP',             'Atende':                    'Todo o Brasil (SPLNs)'},
    {'Código':  'BR23',         'Nome': 'F. Jaguariúna',           'Tipo': 'Cervejaria',              'Localização': 'SP',             'Atende':                    'Todo o Brasil (SPLNs)'},
    {'Código':  'UB541',        'Nome': 'F. Uberlândia',           'Tipo': 'Cervejaria',              'Localização': 'MG',             'Atende':                    'MG e NO Araguaia'},
])

exibir_tabela(unidades)
# Out:
# <style type="text/css">
# #T_57915 table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_57915 th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_57915 td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_57915 tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_57915 tr:hover {
#   background-color: #fff3cd;
# }
# #T_57915_row0_col4, #T_57915_row1_col4, #T_57915_row2_col4, #T_57915_row3_col4, #T_57915_row4_col4, #T_57915_row5_col4, #T_57915_row6_col4 {
#   min-width: 200px;
#   white-space: normal;
# }
# </style>
# <table id="T_57915">
#   <thead>
#     <tr>
#       <th id="T_57915_level0_col0" class="col_heading level0 col0" >Código</th>
#       <th id="T_57915_level0_col1" class="col_heading level0 col1" >Nome</th>
#       <th id="T_57915_level0_col2" class="col_heading level0 col2" >Tipo</th>
#       <th id="T_57915_level0_col3" class="col_heading level0 col3" >Localização</th>
#       <th id="T_57915_level0_col4" class="col_heading level0 col4" >Atende</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_57915_row0_col0" class="data row0 col0" >AQ541 / BR03</td>
#       <td id="T_57915_row0_col1" class="data row0 col1" >F. Aquiraz</td>
#       <td id="T_57915_row0_col2" class="data row0 col2" >Cervejaria</td>
#       <td id="T_57915_row0_col3" class="data row0 col3" >NO Centro (CE)</td>
#       <td id="T_57915_row0_col4" class="data row0 col4" >Todo o Nordeste e Manaus</td>
#     </tr>
#     <tr>
#       <td id="T_57915_row1_col0" class="data row1 col0" >NS541 / BR31</td>
#       <td id="T_57915_row1_col1" class="data row1 col1" >F. Pernambuco</td>
#       <td id="T_57915_row1_col2" class="data row1 col2" >Cervejaria</td>
#       <td id="T_57915_row1_col3" class="data row1 col3" >NE Norte (PE)</td>
#       <td id="T_57915_row1_col4" class="data row1 col4" >Todo o Nordeste</td>
#     </tr>
#     <tr>
#       <td id="T_57915_row2_col0" class="data row2 col0" >BR06</td>
#       <td id="T_57915_row2_col1" class="data row2 col1" >CDR João Pessoa</td>
#       <td id="T_57915_row2_col2" class="data row2 col2" >Centro de Distribuição</td>
#       <td id="T_57915_row2_col3" class="data row2 col3" >NE Norte (PB)</td>
#       <td id="T_57915_row2_col4" class="data row2 col4" >NE Norte, NO Centro, Mapapi</td>
#     </tr>
#     <tr>
#       <td id="T_57915_row3_col0" class="data row3 col0" >BR04</td>
#       <td id="T_57915_row3_col1" class="data row3 col1" >CDR Camaçari / Bahia</td>
#       <td id="T_57915_row3_col2" class="data row3 col2" >Centro de Distribuição</td>
#       <td id="T_57915_row3_col3" class="data row3 col3" >NE Sul (BA)</td>
#       <td id="T_57915_row3_col4" class="data row3 col4" >NE Sul</td>
#     </tr>
#     <tr>
#       <td id="T_57915_row4_col0" class="data row4 col0" >BR16</td>
#       <td id="T_57915_row4_col1" class="data row4 col1" >F. Jacareí</td>
#       <td id="T_57915_row4_col2" class="data row4 col2" >Cervejaria</td>
#       <td id="T_57915_row4_col3" class="data row4 col3" >SP</td>
#       <td id="T_57915_row4_col4" class="data row4 col4" >Todo o Brasil (SPLNs)</td>
#     </tr>
#     <tr>
#       <td id="T_57915_row5_col0" class="data row5 col0" >BR23</td>
#       <td id="T_57915_row5_col1" class="data row5 col1" >F. Jaguariúna</td>
#       <td id="T_57915_row5_col2" class="data row5 col2" >Cervejaria</td>
#       <td id="T_57915_row5_col3" class="data row5 col3" >SP</td>
#       <td id="T_57915_row5_col4" class="data row5 col4" >Todo o Brasil (SPLNs)</td>
#     </tr>
#     <tr>
#       <td id="T_57915_row6_col0" class="data row6 col0" >UB541</td>
#       <td id="T_57915_row6_col1" class="data row6 col1" >F. Uberlândia</td>
#       <td id="T_57915_row6_col2" class="data row6 col2" >Cervejaria</td>
#       <td id="T_57915_row6_col3" class="data row6 col3" >MG</td>
#       <td id="T_57915_row6_col4" class="data row6 col4" >MG e NO Araguaia</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.9 SKUs da Linha Long Neck Premium (NENO)

# %%
skus = pd.DataFrame([
    {'SKU': 'PATAGONIA AMBER LAGER LN355ML CX12',          'Linha Produtiva': 'AQ541',        'Restrição': 'Sem restrição crítica identificada'},
    {'SKU': 'GOOSE ISLAND MIDWAY NAC LN 355ML CX C/12',    'Linha Produtiva': 'NS541',        'Restrição': '⚠️ NO TETO da capacidade de líquido — NÃO pode aumentar produção'},
    {'SKU': 'MALZBIER BRAHMA LN355ML SIX PAC BAND C/4',    'Linha Produtiva': 'AQ541/NS541',  'Restrição': 'Foco do aumento de demanda (+30% em Fev, +10% TT LN em Mar)'},
    {'SKU': 'COLORADO LAGER LN 355ML CX C/12',             'Linha Produtiva': 'AQ541/NS541',  'Restrição': 'Sem restrição crítica identificada'},
    {'SKU': 'BRAHMA CHOPP ZERO LN 355 SIXP CX CART C4',    'Linha Produtiva': 'NS541',        'Restrição': 'Sem restrição crítica identificada'},
    {'SKU': 'SKOL BEATS SENSES LN 269ML SIXPACK SH C4',    'Linha Produtiva': 'NS541',        'Restrição': 'Sem restrição crítica identificada'},
    {'SKU': 'BUDWEISER ZERO LN 330ML SIX-PACK SH C/4',     'Linha Produtiva': 'NS541',        'Restrição': 'Sem restrição crítica identificada'},
])

exibir_tabela(skus)
# Out:
# <style type="text/css">
# #T_b217b table {
#   width: 100%;
#   border-collapse: collapse;
#   font-size: 13px;
#   font-family: Arial, sans-serif;
# }
# #T_b217b th {
#   background-color: #2c2c2c;
#   color: #ffffff;
#   padding: 8px 12px;
#   text-align: left;
#   white-space: nowrap;
# }
# #T_b217b td {
#   padding: 7px 12px;
#   border-bottom: 1px solid #e0e0e0;
#   vertical-align: top;
#   white-space: normal;
#   word-wrap: break-word;
# }
# #T_b217b tr:nth-child(even) {
#   background-color: #f8f8f8;
# }
# #T_b217b tr:hover {
#   background-color: #fff3cd;
# }
# #T_b217b_row0_col2, #T_b217b_row1_col2, #T_b217b_row2_col2, #T_b217b_row3_col2, #T_b217b_row4_col2, #T_b217b_row5_col2, #T_b217b_row6_col2 {
#   min-width: 520px;
#   white-space: normal;
# }
# </style>
# <table id="T_b217b">
#   <thead>
#     <tr>
#       <th id="T_b217b_level0_col0" class="col_heading level0 col0" >SKU</th>
#       <th id="T_b217b_level0_col1" class="col_heading level0 col1" >Linha Produtiva</th>
#       <th id="T_b217b_level0_col2" class="col_heading level0 col2" >Restrição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b217b_row0_col0" class="data row0 col0" >PATAGONIA AMBER LAGER LN355ML CX12</td>
#       <td id="T_b217b_row0_col1" class="data row0 col1" >AQ541</td>
#       <td id="T_b217b_row0_col2" class="data row0 col2" >Sem restrição crítica identificada</td>
#     </tr>
#     <tr>
#       <td id="T_b217b_row1_col0" class="data row1 col0" >GOOSE ISLAND MIDWAY NAC LN 355ML CX C/12</td>
#       <td id="T_b217b_row1_col1" class="data row1 col1" >NS541</td>
#       <td id="T_b217b_row1_col2" class="data row1 col2" >⚠️ NO TETO da capacidade de líquido — NÃO pode aumentar produção</td>
#     </tr>
#     <tr>
#       <td id="T_b217b_row2_col0" class="data row2 col0" >MALZBIER BRAHMA LN355ML SIX PAC BAND C/4</td>
#       <td id="T_b217b_row2_col1" class="data row2 col1" >AQ541/NS541</td>
#       <td id="T_b217b_row2_col2" class="data row2 col2" >Foco do aumento de demanda (+30% em Fev, +10% TT LN em Mar)</td>
#     </tr>
#     <tr>
#       <td id="T_b217b_row3_col0" class="data row3 col0" >COLORADO LAGER LN 355ML CX C/12</td>
#       <td id="T_b217b_row3_col1" class="data row3 col1" >AQ541/NS541</td>
#       <td id="T_b217b_row3_col2" class="data row3 col2" >Sem restrição crítica identificada</td>
#     </tr>
#     <tr>
#       <td id="T_b217b_row4_col0" class="data row4 col0" >BRAHMA CHOPP ZERO LN 355 SIXP CX CART C4</td>
#       <td id="T_b217b_row4_col1" class="data row4 col1" >NS541</td>
#       <td id="T_b217b_row4_col2" class="data row4 col2" >Sem restrição crítica identificada</td>
#     </tr>
#     <tr>
#       <td id="T_b217b_row5_col0" class="data row5 col0" >SKOL BEATS SENSES LN 269ML SIXPACK SH C4</td>
#       <td id="T_b217b_row5_col1" class="data row5 col1" >NS541</td>
#       <td id="T_b217b_row5_col2" class="data row5 col2" >Sem restrição crítica identificada</td>
#     </tr>
#     <tr>
#       <td id="T_b217b_row6_col0" class="data row6 col0" >BUDWEISER ZERO LN 330ML SIX-PACK SH C/4</td>
#       <td id="T_b217b_row6_col1" class="data row6 col1" >NS541</td>
#       <td id="T_b217b_row6_col2" class="data row6 col2" >Sem restrição crítica identificada</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
#
# ## 4. Notas Operacionais Importantes
#
# | Parâmetro | Valor |
# |---|---|
# | DOI mínimo NENO | **12 dias** |
# | Lead time Cabotagem | **25 dias** |
# | Lead time Rodoviário | **6 dias** |
# | Custo Rodoviário vs Cabo | **+60%** |
# | Risco avaria Rodoviário | **+5%** |
# | Capacidade AQ541 | **50 khl/mês** |
# | Capacidade NS541 | **108 khl/mês** |
# | Nova demanda Fev NENO | **192 KHL** |
# | Nova demanda Mar NENO | **211 KHL** |
# | BIAS médio GEOs (últimos 3 meses) | **+9%** |
#
# ---
# *Próxima etapa: Análise Univariada*
